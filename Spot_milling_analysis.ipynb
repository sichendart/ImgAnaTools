# %%
import cv2
import numpy as np
from skimage import measure
import math
import os
from IPython.display import display, Image
import tifffile
import glob

# %%
def detect_measure_and_highlight_circle(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray_crop = gray [:-100]
    
    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray_crop, (1, 1), 0)
    
    # Use Hough Circle Transform to detect circles
    circles = cv2.HoughCircles(
        blurred,
        cv2.HOUGH_GRADIENT,
        dp=1,
        minDist=50,
        param1=50,
        param2=30,
        minRadius=0,
        maxRadius=0
    )
    
    if circles is not None:
        circles = np.uint16(np.around(circles))
        
        # Get the first detected circle
        x, y, r = circles[0][0]
        
        # Calculate diameter
        diameter = 2 * r
        
        # Create a binary mask of the circle
        mask = np.zeros(gray.shape, dtype=np.uint8)
        cv2.circle(mask, (x, y), r, 255, -1)
        
        # Find contours of the mask
        contours = measure.find_contours(mask, 0.5)
        
        if contours:
            contour = contours[0]
            
            # Calculate area and perimeter
            area = cv2.contourArea(contour.astype(np.float32))
            perimeter = cv2.arcLength(contour.astype(np.float32), True)
            
            # Calculate circularity
            circularity = 4 * math.pi * area / (perimeter ** 2)
            
            # Calculate roundness
            _, (major_axis, minor_axis), _ = cv2.fitEllipse(contour.astype(np.float32))
            roundness = min(4 * area / (math.pi * major_axis ** 2), 1.0)
            
            # Draw the circle on the original image
            cv2.circle(image, (x, y), r, (0, 255, 0), 2)
            cv2.circle(image, (x, y), 2, (0, 0, 255), 3)
            
            # Add text with measurements
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.putText(image, f"Diameter: {diameter}px", (10, 30), font, 0.7, (255, 255, 255), 2)
            cv2.putText(image, f"Circularity: {circularity:.4f}", (10, 60), font, 0.7, (255, 255, 255), 2)
            cv2.putText(image, f"Roundness: {roundness:.4f}", (10, 90), font, 0.7, (255, 255, 255), 2)
            
            return image, diameter, circularity, roundness
    
    return image, None, None, None

# %%
def save_analysis_image(original_path, analyzed_image):
    # Get the directory and filename of the original image
    directory, filename = os.path.split(original_path)
    
    # Create the 'analysis' folder if it doesn't exist
    analysis_folder = os.path.join(directory, 'analysis')
    os.makedirs(analysis_folder, exist_ok=True)
    
    # Create the new filename with 'ana' appended and .tiff extension
    name, _ = os.path.splitext(filename)
    new_filename = f"{name}_ana.tiff"
    
    # Save the analyzed image in the 'analysis' folder as TIFF
    save_path = os.path.join(analysis_folder, new_filename)
    tifffile.imwrite(save_path, cv2.cvtColor(analyzed_image, cv2.COLOR_BGR2RGB))
    
    return save_path

# %%
def process_images_in_directory(directory):
    # Get all TIFF files in the directory
    tiff_files = glob.glob(os.path.join(directory, '*.tiff')) + glob.glob(os.path.join(directory, '*.tif'))
    
    results = []
    
    for image_path in tiff_files:
        # Read the image
        img = cv2.imread(image_path)
        
        # Process the image
        result_image, diameter, circularity, roundness = detect_measure_and_highlight_circle(img)
        
        if diameter is not None:
            # Save the analyzed image
            saved_path = save_analysis_image(image_path, result_image)
            
            results.append({
                'filename': os.path.basename(image_path),
                'diameter': diameter,
                'circularity': circularity,
                'roundness': roundness,
                'saved_path': saved_path
            })
            
            print(f"Processed: {os.path.basename(image_path)}")
            print(f"  Diameter: {diameter} pixels")
            print(f"  Circularity: {circularity:.4f}")
            print(f"  Roundness: {roundness:.4f}")
            print(f"  Saved to: {saved_path}")
            print()
        else:
            print(f"No circle detected in: {os.path.basename(image_path)}")
    
    return results

# %%
directory_path = "/Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/"  # Update this path
results = process_images_in_directory(directory_path)
# Out:
# Processed: 30kV-100nA_008.tif
#   Diameter: 170 pixels
#   Circularity: 0.8920
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-100nA_008_ana.tiff
#
# Processed: 30kV-100nA_009.tif
#   Diameter: 168 pixels
#   Circularity: 0.8948
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-100nA_009_ana.tiff
#
# Processed: 30kV-1nA-spot4_009.tif
#   Diameter: 218 pixels
#   Circularity: 0.8924
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-1nA-spot4_009_ana.tiff
#
# Processed: 30kV-1nA-spot1_006.tif
#   Diameter: 546 pixels
#   Circularity: 0.8963
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-1nA-spot1_006_ana.tiff
#
# Processed: 30nA-spot5_026.tif
#   Diameter: 234 pixels
#   Circularity: 0.8946
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30nA-spot5_026_ana.tiff
#
# Processed: 10kV-1nA_21.tif
#   Diameter: 100 pixels
#   Circularity: 0.8923
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/10kV-1nA_21_ana.tiff
#
# No circle detected in: 30kV-2uA_06.tif
# Processed: 100pA-spot2_003.tif
#   Diameter: 192 pixels
#   Circularity: 0.8952
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/100pA-spot2_003_ana.tiff
#
# Processed: 30kV-2uA_12.tif
#   Diameter: 74 pixels
#   Circularity: 0.8835
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-2uA_12_ana.tiff
#
# Processed: 30kV-2uA_13.tif
#   Diameter: 62 pixels
#   Circularity: 0.8872
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-2uA_13_ana.tiff
#
# Processed: 30kV-2uA_07.tif
#   Diameter: 516 pixels
#   Circularity: 0.8978
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-2uA_07_ana.tiff
#
# Processed: 10kV-1nA_20.tif
#   Diameter: 96 pixels
#   Circularity: 0.8922
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/10kV-1nA_20_ana.tiff
#
# Processed: 3kV-1nA_09.tif
#   Diameter: 982 pixels
#   Circularity: 0.4559
#   Roundness: 0.1545
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/3kV-1nA_09_ana.tiff
#
# Processed: 10kV-1nA_22.tif
#   Diameter: 94 pixels
#   Circularity: 0.8874
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/10kV-1nA_22_ana.tiff
#
# Processed: 30kV-2uA_11.tif
#   Diameter: 66 pixels
#   Circularity: 0.8866
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-2uA_11_ana.tiff
#
# Processed: 30kV-2uA_10.tif
#   Diameter: 76 pixels
#   Circularity: 0.8875
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-2uA_10_ana.tiff
#
# Processed: 10kV-1nA_23.tif
#   Diameter: 96 pixels
#   Circularity: 0.8922
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/10kV-1nA_23_ana.tiff
#
# Processed: 100pA-spot3_004.tif
#   Diameter: 188 pixels
#   Circularity: 0.8964
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/100pA-spot3_004_ana.tiff
#
# Processed: 3kV-1nA_08.tif
#   Diameter: 670 pixels
#   Circularity: 0.9026
#   Roundness: 0.9966
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/3kV-1nA_08_ana.tiff
#
# Processed: 100pA-spot1_059.tif
#   Diameter: 242 pixels
#   Circularity: 0.8930
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/100pA-spot1_059_ana.tiff
#
# Processed: 30kV-1nA-spot2_007.tif
#   Diameter: 562 pixels
#   Circularity: 0.8978
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-1nA-spot2_007_ana.tiff
#
# Processed: 30nA-spot4_025.tif
#   Diameter: 230 pixels
#   Circularity: 0.8960
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30nA-spot4_025_ana.tiff
#
# Processed: 10kV-1nA_18.tif
#   Diameter: 94 pixels
#   Circularity: 0.8874
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/10kV-1nA_18_ana.tiff
#
# Processed: 10kV-1nA_19.tif
#   Diameter: 92 pixels
#   Circularity: 0.8812
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/10kV-1nA_19_ana.tiff
#
# Processed: 50kV-1nA_01.tif
#   Diameter: 96 pixels
#   Circularity: 0.8922
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/50kV-1nA_01_ana.tiff
#
# Processed: 50kV-1nA_02.tif
#   Diameter: 94 pixels
#   Circularity: 0.8874
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/50kV-1nA_02_ana.tiff
#
# Processed: 50kV-1nA_03.tif
#   Diameter: 98 pixels
#   Circularity: 0.8860
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/50kV-1nA_03_ana.tiff
#
# Processed: 3kV-1nA_11.tif
#   Diameter: 984 pixels
#   Circularity: 0.4460
#   Roundness: 0.1442
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/3kV-1nA_11_ana.tiff
#
# Processed: 30kV-2uA_09.tif
#   Diameter: 76 pixels
#   Circularity: 0.8875
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-2uA_09_ana.tiff
#
# Processed: 30kV-2uA_08.tif
#   Diameter: 76 pixels
#   Circularity: 0.8875
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-2uA_08_ana.tiff
#
# Processed: 3kV-1nA_10.tif
#   Diameter: 838 pixels
#   Circularity: 0.5790
#   Roundness: 0.2986
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/3kV-1nA_10_ana.tiff
#
# Processed: 50kV-1nA_06.tif
#   Diameter: 98 pixels
#   Circularity: 0.8860
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/50kV-1nA_06_ana.tiff
#
# Processed: 30kV-1nA-spot3_008.tif
#   Diameter: 556 pixels
#   Circularity: 0.8601
#   Roundness: 0.8631
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-1nA-spot3_008_ana.tiff
#
# Processed: 50kV-1nA_04.tif
#   Diameter: 88 pixels
#   Circularity: 0.8851
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/50kV-1nA_04_ana.tiff
#
# Processed: 3kV-1nA_12.tif
#   Diameter: 842 pixels
#   Circularity: 0.5596
#   Roundness: 0.2724
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/3kV-1nA_12_ana.tiff
#
# Processed: 30nA-spot1_022.tif
#   Diameter: 236 pixels
#   Circularity: 0.8967
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30nA-spot1_022_ana.tiff
#
# Processed: 3kV-1nA_07.tif
#   Diameter: 830 pixels
#   Circularity: 0.8869
#   Roundness: 0.9246
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/3kV-1nA_07_ana.tiff
#
# Processed: 3kV-1nA_13.tif
#   Diameter: 922 pixels
#   Circularity: 0.5257
#   Roundness: 0.2300
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/3kV-1nA_13_ana.tiff
#
# Processed: 50kV-1nA_05.tif
#   Diameter: 96 pixels
#   Circularity: 0.8922
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/50kV-1nA_05_ana.tiff
#
# Processed: 100pA-spot4_005.tif
#   Diameter: 196 pixels
#   Circularity: 0.8946
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/100pA-spot4_005_ana.tiff
#
# Processed: 100pA-spot20002.tif
#   Diameter: 116 pixels
#   Circularity: 0.8859
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/100pA-spot20002_ana.tiff
# Processed: 30kV-100nA_010.tif
#   Diameter: 150 pixels
#   Circularity: 0.8895
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-100nA_010_ana.tiff
#
# Processed: 30kV-100nA_011.tif
#   Diameter: 142 pixels
#   Circularity: 0.8910
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-100nA_011_ana.tiff
#
# Processed: 30nA-spot2_023.tif
#   Diameter: 236 pixels
#   Circularity: 0.8967
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30nA-spot2_023_ana.tiff
#
# Processed: 30kV-1nA-spot5_010.tif
#   Diameter: 436 pixels
#   Circularity: 0.8962
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-1nA-spot5_010_ana.tiff
#
# Processed: 30nA-spot3_024.tif
#   Diameter: 236 pixels
#   Circularity: 0.8967
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30nA-spot3_024_ana.tiff
#
# Processed: 30kV-100nA_007.tif
#   Diameter: 172 pixels
#   Circularity: 0.8943
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-100nA_007_ana.tiff
#
# Processed: 30kV-100nA_006.tif
#   Diameter: 174 pixels
#   Circularity: 0.8905
#   Roundness: 1.0000
#   Saved to: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30kV-100nA_006_ana.tiff

# %%
print("Summary of processed images:")
for result in results:
    print(f"File: {result['filename']}")
    print(f"  Diameter: {result['diameter']} pixels")
    print(f"  Circularity: {result['circularity']:.4f}")
    print(f"  Roundness: {result['roundness']:.4f}")
    print(f"  Analyzed image: {result['saved_path']}")
    print()

    # Display the first few processed images
    if results.index(result) < 3:  # Limit to first 3 images to avoid cluttering the notebook
        display(Image(filename=result['saved_path']))

# Explicitly save the notebook
from IPython.display import Javascript
display(Javascript('IPython.notebook.save_checkpoint();'))
print("Notebook saved.")
# Out:
# Summary of processed images:
# File: 30nA-spot1_022.tif
#   Diameter: 242 pixels
#   Circularity: 0.8930
#   Roundness: 1.0000
#   Analyzed image: /Users/sichen/Box Sync/projects/2021_ECRP/data/202409_Xe_spot_milling/analysis/30nA-spot1_022_ana.tiff
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 12
#      10     # Display the first few processed images
#      11     if results.index(result) < 3:  # Limit to first 3 images to avoid cluttering the notebook
# ---> 12         display(Image(filename=result['saved_path']))
#      14 # Explicitly save the notebook
#      15 from IPython.display import Javascript
#
# File /opt/anaconda3/lib/python3.11/site-packages/IPython/core/display.py:961, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     958 self.embed = embed if embed is not None else (url is None)
#     960 if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 961     raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     962 if self.embed:
#     963     self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'tiff' image format
